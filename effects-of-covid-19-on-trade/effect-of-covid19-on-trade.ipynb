# %% [markdown]
# # VISUALISING THE EFFECTS OF COVID19 ON TRADE

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import openpyxl #must be installed
from importlib import reload 
plt=reload(plt)

# %% [markdown]
# ## 1. Read the data that is in the file and display it

# %%
df = pd.read_csv("data.csv")
df
# Out:
#       Direction  Year        Date    Weekday Current_Match Country Commodity  \
# 0       Exports  2015  31/01/2015   Saturday    01/02/2020     All       All
# 1       Exports  2015  01/02/2015     Sunday    02/02/2020     All       All
# 2       Exports  2015  02/02/2015     Monday    03/02/2020     All       All
# 3       Exports  2015  03/02/2015    Tuesday    04/02/2020     All       All
# 4       Exports  2015  04/02/2015  Wednesday    05/02/2020     All       All
# ...         ...   ...         ...        ...           ...     ...       ...
# 53249   Reimpor  2020  05/09/2020   Saturday    05/09/2020     All       All
# 53250   Reimpor  2020  06/09/2020     Sunday    06/09/2020     All       All
# 53251   Reimpor  2020  07/09/2020     Monday    07/09/2020     All       All
# 53252   Reimpor  2020  08/09/2020    Tuesday    08/09/2020     All       All
# 53253   Reimpor  2020  09/09/2020  Wednesday    09/09/2020     All       All
#
# ...

# %% [markdown]
# ## 2. Getting the data for each year
# * **2015**
#     * (imports and exports value)
# * **2016**
#     * (imports and exports value)
# * **2017**
#     * (imports and exports value)
# * **2018**
#     * (imports and exports value)
# * **2019**
#     * (imports and exports value)
# * **2020**
#     * (imports and exports value)

# %% [markdown]
# ### Index

# %%
index = np.array(df.index)
index
# Out:
# array([    0,     1,     2, ..., 53251, 53252, 53253], dtype=int64)

# %% [markdown]
# ### 2015

# %%
# imports
imp2015 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2015)].Value)
impo2015indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2015)].index)
# exports
exp2015 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2015)].Value)
expo2015indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2015)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2015", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2015 Imports
plt.plot(impo2015indx, imp2015, '-or', markeredgecolor="b")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2015", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2015 Exports
plt.plot(expo2015indx, exp2015, '-ob', markeredgecolor="r")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2015", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2015 Exports
plt.plot(expo2015indx, exp2015, '-ob', markeredgecolor="r", label="2015 exports")
# 2015 Imports
plt.plot(impo2015indx, imp2015, '-or', markeredgecolor="b", label="2015 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2016

# %%
# imports
imp2016 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2016)].Value)
impo2016indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2016)].index)
# exports
exp2016 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2016)].Value)
expo2016indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2016)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2016", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2016 Imports
plt.plot(impo2016indx, imp2016, '-og', markeredgecolor="b")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2016", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2016 Exports
plt.plot(expo2016indx, exp2016, '-oy', markeredgecolor="r")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2016", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2016 Exports
plt.plot(expo2016indx, exp2016, '-oy', markeredgecolor="r", label="2016 exports")
# 2016 Imports
plt.plot(impo2016indx, imp2016, '-og', markeredgecolor="b", label="2016 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2017

# %%
# imports
imp2017 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2017)].Value)
impo2017indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2017)].index)
# exports
exp2017 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2017)].Value)
expo2017indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2017)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2017", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2017 Imports
plt.plot(impo2017indx, imp2017, '-ok', markeredgecolor="b")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2017", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2017 Exports
plt.plot(expo2017indx, exp2017, '-or', markeredgecolor="k")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exoports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2017", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2017 Exports
plt.plot(expo2017indx, exp2017, '-or', markeredgecolor="k", label="2017 exports")
# 2017 Imports
plt.plot(impo2017indx, imp2017, '-ok', markeredgecolor="b", label="2017 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2018

# %%
# imports
imp2018 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2018)].Value)
impo2018indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2018)].index)
# exports
exp2018 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2018)].Value)
expo2018indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2018)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2018", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2018 Imports
plt.plot(impo2018indx, imp2018, '-om', markeredgecolor="b")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2018", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2018 Exports
plt.plot(expo2018indx, exp2018, '-ob', markeredgecolor="m")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exoports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2018", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2018 Exports
plt.plot(expo2018indx, exp2018, '-ob', markeredgecolor="m", label="2018 exports")
# 2018 Imports
plt.plot(impo2018indx, imp2018, '-om', markeredgecolor="b", label="2018 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2019

# %%
# imports
imp2019 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2019)].Value)
impo2019indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2019)].index)
# exports
exp2019 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2019)].Value)
expo2019indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2019)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2019", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2019 Imports
plt.plot(impo2019indx, imp2019, '-oc', markeredgecolor="b")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2016", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2019 Exports
plt.plot(expo2019indx, exp2019, '-ob', markeredgecolor="c")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exoports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2019", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2019 Exports
plt.plot(expo2019indx, exp2019, '-ob', markeredgecolor="c", label="2019 exports")
# 2019 Imports
plt.plot(impo2019indx, imp2019, '-oc', markeredgecolor="b", label="2019 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2020

# %%
# imports
imp2020 = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2020)].Value)
impo2020indx = np.array(df.loc[(df.Direction =="Reimpor") & (df.Year == 2020)].index)
# exports
exp2020 = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2020)].Value)
expo2020indx = np.array(df.loc[(df.Direction =="Exports") & (df.Year == 2020)].index)

# %% [markdown]
# ### 1. Visualisation of Imports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE IMPORTS IN 2020", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2020 Imports
plt.plot(impo2020indx, imp2020, '-og', markeredgecolor="y")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 2. Visualisation of Exports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS IN 2016", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2016 Exports
plt.plot(expo2016indx, exp2016, '-oy', markeredgecolor="g")
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# ### 3. Visualisation of Imports and Exoports

# %%
plt.title("EFFECTS OF COVID19 ON TRADE EXPORTS AND IMPORTS IN 2020", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2020 Exports
plt.plot(expo2020indx, exp2020, '-oy', markeredgecolor="g", label="2020 exports")
# 2020 Imports
plt.plot(impo2020indx, imp2020, '-og', markeredgecolor="y", label="2020 imports")
plt.legend()
plt.rcParams["figure.figsize"] = (10, 5)
plt.rcParams["figure.facecolor"] ='#fafafa'
plt.show()

# %% [markdown]
# # Visualising the data
# * Each year
#     * imports againist index
#     * exports againist index

# %% [markdown]
# ## All In one

# %%
plt.title("EFFECTS OF COVID19 ON TRADE", fontsize=20, fontweight='bold', fontfamily='Arial')
plt.xlabel("INDEX",  fontsize=16, fontweight='bold', fontfamily='Arial' )
plt.ylabel("VALUE (USD)",  fontsize=16, fontweight='bold', fontfamily='Arial')
# 2015 Exports
plt.plot(expo2015indx, exp2015, '-ob', markeredgecolor="r", label="2015 exports")
# 2015 Imports
plt.plot(impo2015indx, imp2015, '-or', markeredgecolor="b", label="2015 imports")

# 2016 Exports
plt.plot(expo2016indx, exp2016, '-oy', markeredgecolor="r", label="2016 exports")
# 2016 Imports
plt.plot(impo2016indx, imp2016, '-og', markeredgecolor="b", label="2016 imports")

# 2017 Exports
plt.plot(expo2017indx, exp2017, '-or', markeredgecolor="k", label="2017 exports")
# 2017 Imports
plt.plot(impo2017indx, imp2017, '-ok', markeredgecolor="b", label="2017 imports")

# 2018 Exports
plt.plot(expo2018indx, exp2018, '-ob', markeredgecolor="m", label="2018 exports")
# 2018 Imports
plt.plot(impo2018indx, imp2018, '-om', markeredgecolor="b", label="2018 imports")

# 2019 Exports
plt.plot(expo2019indx, exp2019, '-ob', markeredgecolor="c", label="2019 exports")
# 2019 Imports
plt.plot(impo2019indx, imp2019, '-oc', markeredgecolor="b", label="2019 imports")


# 2020 Exports
plt.plot(expo2020indx, exp2020, '-oy', markeredgecolor="g", label="2020 exports")
# 2020 Imports
plt.plot(impo2020indx, imp2020, '-og', markeredgecolor="y", label="2020 imports")

plt.legend()
plt.rcParams["figure.figsize"] = (15, 10)
plt.rcParams["figure.facecolor"] ='lightgray'
plt.show()
